# %% [markdown]
# <a href="https://colab.research.google.com/github/henilsolanki1234-del/banking-customer-analysis/blob/main/bankanalysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install mysql-connector-python
# Out:
# ...
#    ---------------------------------------- 0.0/17.7 MB ? eta -:--:--
#     --------------------------------------- 0.3/17.7 MB ? eta -:--:--
#    - -------------------------------------- 0.8/17.7 MB 2.4 MB/s eta 0:00:08
#    -- ------------------------------------- 1.3/17.7 MB 2.8 MB/s eta 0:00:06
#    ---- ----------------------------------- 1.8/17.7 MB 2.9 MB/s eta 0:00:06
#    ----- ---------------------------------- 2.6/17.7 MB 2.9 MB/s eta 0:00:06
#    ------- -------------------------------- 3.4/17.7 MB 3.2 MB/s eta 0:00:05
#    ---------- ----------------------------- 4.5/17.7 MB 3.5 MB/s eta 0:00:04
#    ------------- -------------------------- 5.8/17.7 MB 3.8 MB/s eta 0:00:04
#    --------------- ------------------------ 6.8/17.7 MB 4.0 MB/s eta 0:00:03
#    ----------------- ---------------------- 7.9/17.7 MB 4.2 MB/s eta 0:00:03
#    --------------------- ------------------ 9.4/17.7 MB 4.4 MB/s eta 0:00:02
# ...

# %%
import Local instance MySQL80
import pandas as pd
cnx = Local instance MySQL80(
    host = "127.0.0.1",
    port = 3306,
    users="root",
    password="henil@1202")
# Out:
#   Cell In[6], line 1
#     import Local instance MySQL80
#                  ^
# SyntaxError: invalid syntax

# %%
import mysql.connector
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

conn = mysql.connector.connect(
    host="127.0.0.1",
    user="root",
    password="henil@1202"
)

print("Connected Successfully!")
# Out:
# Connected Successfully!

# %%
query="SELECT * FROM banking_case.customer"

# %%
df=pd.read_sql(query,conn)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_43176\3041742326.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df=pd.read_sql(query,conn)

# %%
conn.close()

# %%
df.head()
# Out:
#   ï»¿Client ID             Name  Age  Location ID Joined Bank  \
# 0     IND81288    Raymond Mills   24        34324  06-05-2019
# 1     IND65833    Julia Spencer   23        42205  10-12-2001
# 2     IND47499   Stephen Murray   27         7314  25-01-2010
# 3     IND72498   Virginia Garza   40        34594  28-03-2019
# 4     IND60181  Melissa Sanders   46        41269  20-07-2012
#
#     Banking Contact Nationality            Occupation Fee Structure  \
# 0    Anthony Torres    American  Safety Technician IV          High
# 1  Jonathan Hawkins     African   Software Consultant          High
# 2     Anthony Berry    European    Help Desk Operator          High
# 3        Steve Diaz    American          Geologist II           Mid
# 4        Shawn Long    American   Assistant Professor           Mid
#
#   Loyalty Classification  ...  Bank Deposits  Checking Accounts  \
# 0                   Jade  ...     1485828.64          603617.88
# ...

# %%
df.shape
# Out:
# (3000, 25)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ï»¿Client ID              3000 non-null   object
#  1   Name                      3000 non-null   object
#  2   Age                       3000 non-null   int64
#  3   Location ID               3000 non-null   int64
#  4   Joined Bank               3000 non-null   object
#  5   Banking Contact           3000 non-null   object
#  6   Nationality               3000 non-null   object
#  7   Occupation                3000 non-null   object
#  8   Fee Structure             3000 non-null   object
#  9   Loyalty Classification    3000 non-null   object
#  10  Estimated Income          3000 non-null   float64
#  11  Superannuation Savings    3000 non-null   float64
#  12  Amount of Credit Cards    3000 non-null   int64
# ...

# %%
df.describe()
# Out:
#                Age   Location ID  Estimated Income  Superannuation Savings  \
# count  3000.000000   3000.000000       3000.000000             3000.000000
# mean     51.039667  21563.323000     171305.034263            25531.599673
# std      19.854760  12462.273017     111935.808209            16259.950770
# min      17.000000     12.000000      15919.480000             1482.030000
# 25%      34.000000  10803.500000      82906.595000            12513.775000
# 50%      51.000000  21129.500000     142313.480000            22357.355000
# 75%      69.000000  32054.500000     242290.305000            35464.740000
# max      85.000000  43369.000000     522330.260000            75963.900000
#
#        Amount of Credit Cards  Credit Card Balance    Bank Loans  \
# count             3000.000000          3000.000000  3.000000e+03
# mean                 1.463667          3176.206943  5.913862e+05
# std                  0.676387          2497.094709  4.575570e+05
# ...

# %%
df.isnull().sum()
# Out:
# ï»¿Client ID                0
# Name                        0
# Age                         0
# Location ID                 0
# Joined Bank                 0
# Banking Contact             0
# Nationality                 0
# Occupation                  0
# Fee Structure               0
# Loyalty Classification      0
# Estimated Income            0
# Superannuation Savings      0
# Amount of Credit Cards      0
# Credit Card Balance         0
# Bank Loans                  0
# Bank Deposits               0
# Checking Accounts           0
# Saving Accounts             0
# Foreign Currency Account    0
# Business Lending            0
# Properties Owned            0
# Risk Weighting              0
# BRId                        0
# GenderId                    0
# IAId                        0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['Bank Deposits'].value_counts()
# Out:
# Bank Deposits
# 0.00          34
# 1485828.64     1
# 1675743.29     1
# 748509.94      1
# 1013382.00     1
#               ..
# 1112405.11     1
# 591197.27      1
# 1002810.16     1
# 153872.47      1
# 65617.66       1
# Name: count, Length: 2967, dtype: int64

# %%
df['Bank Loans'].value_counts()
# Out:
# Bank Loans
# 0.00          27
# 639113.19      2
# 776242.92      1
# 540883.97      1
# 510642.72      1
#               ..
# 1333483.38     1
# 1561287.22     1
# 322551.54      1
# 532788.31      1
# 285640.66      1
# Name: count, Length: 2973, dtype: int64

# %%
#check the age distribution of customers
df['Age'].describe()
# Out:
# count    3000.000000
# mean       51.039667
# std        19.854760
# min        17.000000
# 25%        34.000000
# 50%        51.000000
# 75%        69.000000
# max        85.000000
# Name: Age, dtype: float64

# %%
#visualize custoer age distribution

plt.hist(df['Age'], bins=20)
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Number of Customers')
plt.show()

# %%
#analyse bank deposit statics
df['Bank Deposits'].describe()
# Out:
# count    3.000000e+03
# mean     6.715602e+05
# std      6.457169e+05
# min      0.000000e+00
# 25%      2.044004e+05
# 50%      4.633165e+05
# 75%      9.427546e+05
# max      3.890598e+06
# Name: Bank Deposits, dtype: float64

# %%
#identify top 10 customers with highest deposits
df.nlargest(10,'Bank Deposits')[['Name','Bank Deposits']]
# Out:
#                   Name  Bank Deposits
# 640        Ronald Reed     3890598.08
# 2307       Harry Burns     3863355.50
# 1132      Craig Hansen     3808500.26
# 1819      Harry Gibson     3784994.65
# 1643  Johnny Patterson     3760505.45
# 2109      John Frazier     3667387.28
# 952         Scott Hart     3515972.56
# 376         Wayne Hart     3498983.55
# 2594   Martin Marshall     3466323.35
# 2567     Clarence Hart     3386869.41

# %%
# analyse bank loan statistics
df['Bank Loans'].describe()
# Out:
# count    3.000000e+03
# mean     5.913862e+05
# std      4.575570e+05
# min      0.000000e+00
# 25%      2.396281e+05
# 50%      4.797934e+05
# 75%      8.258130e+05
# max      2.667557e+06
# Name: Bank Loans, dtype: float64

# %%
#identify top 10 customer with highest loan
df.nlargest(10,'Bank Loans')[['Name','Bank Loans']]
# Out:
#                 Name  Bank Loans
# 2704   Ryan Mitchell  2667556.66
# 2097    Terry Chavez  2584311.14
# 2628  Russell Wagner  2538730.13
# 1334     Sean Pierce  2439164.14
# 760   Ralph Sullivan  2381138.32
# 1595   Sean Harrison  2374318.47
# 1132    Craig Hansen  2349148.32
# 2802    Larry Cooper  2348592.06
# 952       Scott Hart  2333487.55
# 2772   Daniel Flores  2331797.04

# %%
#find most common occupation
df['Occupation'].value_counts()
# Out:
# Occupation
# Structural Analysis Engineer    28
# Associate Professor             28
# Recruiter                       25
# Human Resources Manager         24
# Account Coordinator             24
#                                 ..
# Office Assistant IV              8
# Automation Specialist I          7
# Computer Systems Analyst I       6
# Developer III                    5
# Senior Sales Associate           4
# Name: count, Length: 195, dtype: int64

# %%
#identify top 10 common occupation of customers
df['Occupation'].value_counts().head(10).plot(kind='bar')
plt.title('Top 10 Occupations')
plt.show()

# %%
#analyse customer loyalty categories
df['Nationality'].value_counts()
# Out:
# Nationality
# European      1309
# Asian          754
# American       507
# Australian     254
# African        176
# Name: count, dtype: int64

# %%
df['Fee Structure'].value_counts()
# Out:
# Fee Structure
# High    1476
# Mid      962
# Low      562
# Name: count, dtype: int64

# %%
df['Loyalty Classification'].value_counts()
# Out:
# Loyalty Classification
# Jade        1331
# Silver       767
# Gold         585
# Platinum     317
# Name: count, dtype: int64

# %%
#count credit card amounts
df['Amount of Credit Cards'].value_counts()
# Out:
# Amount of Credit Cards
# 1    1922
# 2     765
# 3     313
# Name: count, dtype: int64

# %%
#analyse credit card balanced
df['Credit Card Balance'].mean()
# Out:
# np.float64(3176.2069433333336)

# %%
numeric_df = df.select_dtypes(include=['int64','float64'])

corr = numeric_df.corr()

import seaborn as sns
plt.figure(figsize=(12,8))
sns.heatmap(corr, annot=True)
plt.show()
